# %%
# !pip install torch torchaudio datasets librosa scikit-learn

# %% [markdown]
# Question3 Code blocks are below.

# %%
# !python audit.py
# Out:
# Loading dataset (fast subset)...
# Resolving data files: 100% 48/48 [00:00<00:00, 227230.92it/s]
# Resolving data files: 100% 48/48 [00:00<00:00, 284761.80it/s]
# Loaded 1916 samples
# Unique speakers: 18
# Gender Distribution: Counter({'male': 11, 'female': 7})
# Age Distribution: Counter({'young': 10, 'old': 8})

# %%
# !python privacymodule.py

# %%
# !pip install torchaudio

# %%
# !python pp_demo.py
# Out:
# /usr/local/lib/python3.12/dist-packages/torchaudio/functional/functional.py:581: UserWarning: At least one mel filterbank has all zero values. The value for `n_mels` (128) may be set too high. Or, the value for `n_freqs` (201) may be set too low.
#   warnings.warn(
# Original MFCC: torch.Size([1, 40, 81])
# Obfuscated MFCC: torch.Size([1, 40, 81])

# %%
# !python train_fair.py
# Out:
# Main Loss: 2.9109694957733154
# Fairness Loss: 2.890618085861206
# Total Loss: 3.200031280517578

# %%
# Example dummy audio (replace with real audio)
audio = torch.randn(16000)

# Extract MFCC
mfcc = extract_mfcc(audio)

# Apply privacy module
obfuscator = PrivacyObfuscator()
mfcc_private = obfuscator(mfcc)

print("MFCC shape:", mfcc.shape)
print("Obfuscated MFCC shape:", mfcc_private.shape)
# Out:
# MFCC shape: torch.Size([1, 40, 101])
# Obfuscated MFCC shape: torch.Size([1, 40, 101])

# %%
import torch.nn as nn
import torch

# Loss function
criterion = nn.CrossEntropyLoss()

# Dummy example (replace with your real outputs)
outputs = torch.randn(32, 18)  # batch of 32, 18 speakers
labels = torch.randint(0, 18, (32,))

# Simulated groups (for fairness)
group_labels = torch.randint(0, 2, (32,))

# Fairness loss function
def fairness_loss(outputs, labels, group_labels):
    group_acc = []
    unique_groups = set(group_labels.tolist())

    for g in unique_groups:
        idx = (group_labels == g).nonzero(as_tuple=True)[0]
        if len(idx) == 0:
            continue

        preds = outputs[idx].argmax(dim=1)
        acc = (preds == labels[idx]).float().mean()
        group_acc.append(acc)

    if len(group_acc) > 1:
        return torch.var(torch.stack(group_acc))
    else:
        return torch.tensor(0.0)

# Compute losses
lambda_fair = 0.1

loss_main = criterion(outputs, labels)
loss_fair = fairness_loss(outputs, labels, group_labels)

loss = loss_main + lambda_fair * loss_fair

print("Main Loss:", loss_main.item())
print("Fairness Loss:", loss_fair.item())
print("Total Loss:", loss.item())
# Out:
# Main Loss: 3.137253999710083
# Fairness Loss: 0.018974533304572105
# Total Loss: 3.1391513347625732
